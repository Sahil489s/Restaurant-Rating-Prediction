# %% [markdown]
# #"This is the first internship project assigned by Cognifyz Technologies."

# %% [markdown]
# #Level-1

# %% [markdown]
# #Importing dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns; sns.set(color_codes=True)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Task-1(Data Exploration and Preprocessing)

# %% [markdown]
# # loading the dataset

# %%
pd.set_option("display.max_column" ,None)

# %%
df = pd.read_csv('/content/Dataset .csv')

# %% [markdown]
# # Data Exploration And Preprocessing

# %%
df.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
print(df.describe())
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
print(f'The dataset contains {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
# The dataset contains 9551 rows and 21 columns.

# %% [markdown]
# #Checking for missing values in each column

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# #only the "Cuisines" column has missing values (9 in total),
# so there are limited number of missing values in that case we fill these missing values using mode imputaion.

# %%
df['Cuisines'] = df['Cuisines'].fillna(df['Cuisines'].mode()[0])

# %%
df['Cuisines'].isna().sum()
# Out:
# 0

# %%
df['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian                                             945
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %% [markdown]
# ##Analyze the distribution of the target variable ("Aggregate rating") and identify any class imbalances.

# %%
df['Aggregate rating'].describe()
# Out:
# count    9551.000000
# mean        2.666370
# std         1.516378
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %%
# Plot the distribution of Aggregate rating
plt.figure(figsize=(10, 6))
sns.histplot(df['Aggregate rating'], kde=True, bins=20)
plt.title('Distribution of Aggregate Rating')
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #Task-2(Descriptive Analysis)

# %% [markdown]
# ##Calculate basic statistical measures (mean,median, standar deviation, etc.) for numerical columns

# %%
print(df.describe())
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df[['Average Cost for two','Price range','Aggregate rating','Votes']].describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [markdown]
# ##Explore the distribution of categorical variables like "Country Code," "City," and"Cuisines.Identify the top cuisines and cities with the highest number of restaurants

# %%
df['Country Code'].value_counts()
# Out:
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %%
# Plot distribution of 'Country Code'
plt.figure(figsize=(10, 6))
sns.countplot(x='Country Code', data=df)
plt.title('Distribution of Country Code')
plt.xlabel('Country Code')
plt.ylabel('Count')
plt.show()

# %%
top_10_country_codes = df['Country Code'].value_counts().head(10).index

top_10_df = df[df['Country Code'].isin(top_10_country_codes)]

# Plot the distribution of the top 10 country codes
plt.figure(figsize=(12, 6))
sns.countplot(x='Country Code', data=top_10_df, order=top_10_country_codes)
plt.title('Distribution of Top 10 Country Codes')
plt.xlabel('Country Code')
plt.ylabel('Count')
plt.show()

# %%
# Get the top 10 cities with the highest number of restaurants
top_10_cities = df['City'].value_counts().head(10)

# Plot the data
plt.figure(figsize=(14, 7))
sns.barplot(x=top_10_cities.index, y=top_10_cities.values, palette='viridis')
plt.title('Top 10 Cities with the Highest Number of Restaurants')
plt.xlabel('City')
plt.ylabel('Number of Restaurants')
plt.show()

# %%
# Get the top 10 cuisines with the highest number of restaurants
top_10_cuisines = df['Cuisines'].value_counts().head(10)

# Plot the data
plt.figure(figsize=(14, 7))
sns.barplot(x=top_10_cuisines.index, y=top_10_cuisines.values, palette='magma')
plt.title('Top 10 Cuisines with the Highest Number of Restaurants')
plt.xlabel('Cuisine')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45)  # Rotate x-ticks for better visibility
plt.show()

# %% [markdown]
# #Task-3(Geospatial Analysis)

# %% [markdown]
# ##Analyze the distribution of restaurants across different cities or countries

# %%
city_counts = df['City'].value_counts().head(15)

# Plot the distribution of restaurants in top 15 cities
plt.figure(figsize=(18, 6))
sns.barplot(x=city_counts.index, y=city_counts.values, palette='viridis')
plt.title('Distribution of Restaurant Across Cities')
plt.xlabel('City')
plt.ylabel('Number of Restaurants')
plt.show()

# %% [markdown]
# ##Determine if there is any correlation between the restaurant's location and its rating

# %%
plt.figure(figsize=(10, 6))
correlation_matrix = df[['Latitude', 'Longitude', 'Aggregate rating']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation between Restaurant's location and rating")
plt.show()

# %% [markdown]
# #**Level**-**2**

# %% [markdown]
# #Task-1( Table Booking and Online Delivery)

# %% [markdown]
# ##Determine the percentage of restaurants that offer table booking and online delivery

# %%
df['Has Table booking'].value_counts()
# Out:
# Has Table booking
# No     8393
# Yes    1158
# Name: count, dtype: int64

# %%
print('Table booking:', round((1158/(8393+1158))*100,2),'%')
# Out:
# Table booking: 12.12 %

# %%
print('online delivery:', round((2451/(7100+2451))*100,2),'%')
# Out:
# online delivery: 25.66 %

# %%
df['Has Online delivery'].value_counts()
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
Table_booking=df['Has Table booking'].value_counts().get('Yes')
Online_delivery=df['Has Online delivery'].value_counts().get('Yes')

percentage_table_booking = (Table_booking/len(df)) * 100
percentage_online_delivery = (Online_delivery /len (df)) * 100

print(f"Percentage of restaurants that offer table booking: {percentage_table_booking:.2f}%")
print(f"Percentage of restaurants that offer online delivery: {percentage_online_delivery:.2f}%")
# Out:
# Percentage of restaurants that offer table booking: 12.12%
# Percentage of restaurants that offer online delivery: 25.66%

# %% [markdown]
# ##Compare the average ratings of restaurants with table booking and those without

# %%
# Filter the dataset into two groups: with table booking and without table booking
with_table_booking = df[df['Has Table booking'] == 'Yes']
without_table_booking = df[df['Has Table booking'] == 'No']


average_rating_with_booking = with_table_booking['Aggregate rating'].mean()
average_rating_without_booking = without_table_booking['Aggregate rating'].mean()

print(f"Average rating for restaurants with table booking: {average_rating_with_booking:.2f}")
print(f"Average rating for restaurants without table booking: {average_rating_without_booking:.2f}")
# Out:
# Average rating for restaurants with table booking: 3.44
# Average rating for restaurants without table booking: 2.56

# %% [markdown]
# ##Analyze the availability of online delivery among restaurants with different price ranges

# %%
# Group the data by 'Price range' and count occurrences of 'Yes' and 'No' in 'Has Online delivery'
online_delivery_by_price_range = df.groupby('Price range')['Has Online delivery'].value_counts().unstack().fillna(0)

# Plotting the stacked bar chart
online_delivery_by_price_range.plot(kind='bar', stacked=True, figsize=(10, 6), color=['#1f77b4', '#ff7f0e'])

plt.title('Availability of Online Delivery by Price Range', fontsize=14)
plt.xlabel('Price Range', fontsize=12)
plt.ylabel('Count of Restaurants', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Online Delivery', labels=['No', 'Yes'])
plt.tight_layout()

plt.show()

# %%
online_delivery_by_price_range = df.groupby('Price range')['Has Online delivery'].value_counts(normalize=True).unstack()

online_delivery_by_price_range['Online Delivery (%)'] = online_delivery_by_price_range['Yes'] * 100

print(online_delivery_by_price_range[['Online Delivery (%)']])
# Out:
# Has Online delivery  Online Delivery (%)
# Price range
# 1                              15.774077
# 2                              41.310633
# 3                              29.190341
# 4                               9.044369

# %%
online_delivery_by_price_range = df.groupby('Price range')['Has Online delivery'].value_counts().unstack().fillna(0)

# Create a bar plot for the counts of restaurants offering online delivery
plt.figure(figsize=(10, 6))
sns.barplot(x=online_delivery_by_price_range.index, y=online_delivery_by_price_range['Yes'], palette='viridis')

plt.title('Count of Restaurants Offering Online Delivery by Price Range', fontsize=14)
plt.xlabel('Price Range', fontsize=12)
plt.ylabel('Count of Restaurants with Online Delivery', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# #Task-2(Price Range Analysis)

# %% [markdown]
# ##Determine the most common price range among all the restaurants

# %%
df['Price range'].value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
most_common_price_range = df['Price range'].value_counts().idxmax()
print("The most common price range among all the restaurants is:",most_common_price_range)
# Out:
# The most common price range among all the restaurants is: 1

# %% [markdown]
# ##Calculate the average rating for each price range

# %%
average_rating_by_price_range = df.groupby('Price range')['Aggregate rating'].mean()
print("Average Rating for each price range:")
print(average_rating_by_price_range)
# Out:
# Average Rating for each price range:
# Price range
# 1    1.999887
# 2    2.941054
# 3    3.683381
# 4    3.817918
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# ##Identify the color that represents the highest average rating among different price ranges

# %%
Highest_avg_rating_color=average_rating_by_price_range.idxmax()
plt.bar(average_rating_by_price_range.index,average_rating_by_price_range,color='Skyblue',width=0.5)
plt.bar(Highest_avg_rating_color,average_rating_by_price_range[Highest_avg_rating_color],color="green",width=0.5)
plt.xlabel('Price Range')
plt.ylabel('Average Rating')
plt.title('Average Rating by Price Range')
plt.show()

# %% [markdown]
# #Task-3(Feature Engineering)

# %% [markdown]
# ##Extract additional features from the existing columns, such as the length of the restaurant name or address

# %%
df['Restaurant Name Length'] = df['Restaurant Name'].apply(lambda x: len(str(x)))
df['Address Length'] = df['Address'].apply(lambda x: len(str(x)))

# %%
df[['Restaurant Name','Restaurant Name Length','Address','Address Length']]
# Out:
#                Restaurant Name  Restaurant Name Length  \
# 0             Le Petit Souffle                      16
# 1             Izakaya Kikufuji                      16
# 2       Heat - Edsa Shangri-La                      22
# 3                         Ooma                       4
# 4                  Sambo Kojin                      11
# ...                        ...                     ...
# 9546               Naml۱ Gurme                      11
# 9547              Ceviz A��ac۱                      12
# 9548                     Huqqa                       5
# 9549               A���k Kahve                      11
# 9550  Walter's Coffee Roastery                      24
#
#                                                 Address  Address Length
# 0     Third Floor, Century City Mall, Kalayaan Avenu...              71
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...              67
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...              56
# ...

# %% [markdown]
# ##Create new features like "Has Table Booking"or "Has Online Delivery" by encoding categorical variables

# %%
df['Has Table Booking'] = df['Has Table booking'].apply(lambda x: 1 if x == 'Yes' else 0)
df['Has Online Delivery'] = df['Has Online delivery'].apply(lambda x: 1 if x == 'Yes' else 0)

# %% [markdown]
# ###1 indicates 'yes' that means restaurant has table Booking
# ###0 indicates 'no' that means that means restaurant does not provide online delivery

# %%
print(df[['Has Table booking', 'Has Table Booking', 'Has Online delivery', 'Has Online Delivery']])
# Out:
#      Has Table booking  Has Table Booking Has Online delivery  \
# 0                  Yes                  1                  No
# 1                  Yes                  1                  No
# 2                  Yes                  1                  No
# 3                   No                  0                  No
# 4                  Yes                  1                  No
# ...                ...                ...                 ...
# 9546                No                  0                  No
# 9547                No                  0                  No
# 9548                No                  0                  No
# 9549                No                  0                  No
# 9550                No                  0                  No
#
#       Has Online Delivery
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 9546                    0
# ...

# %% [markdown]
# #Level-3

# %% [markdown]
# #Task-1(Predictive Modeling)

# %% [markdown]
# # Encoding categorical features

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Encoding categorical features
le = LabelEncoder()
df['Has Table booking'] = df['Has Table booking'].map({'Yes': 1, 'No': 0})
df['Has Online delivery'] = df['Has Online delivery'].map({'Yes': 1, 'No': 0})
df['Is delivering now'] = df['Is delivering now'].map({'Yes': 1, 'No': 0})
df['Switch to order menu'] = df['Switch to order menu'].map({'Yes': 1, 'No': 0})
df['Rating text'] = df['Rating text'].map({'Excellent': 5, 'Very Good': 4, 'Good': 3, 'Average': 2, 'Poor': 1, 'Not rated': 0 })

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# ##Feature Selection

# %%
# Select the features (X) and target (y)
x = df[['Longitude', 'Latitude', 'Average Cost for two', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Price range', 'Rating text', 'Votes']]
y = df['Aggregate rating']

# %% [markdown]
# ##Spliting the dataset into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Feature Scaling (Normalization)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## model Selection & Fitting

# %% [markdown]
# ##LinearRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Model training and evaluation
model = LinearRegression()
model.fit(X_train_scaled, y_train)

y_pred = model.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Model: LinearRegression")
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Model: LinearRegression
# Mean Squared Error: 0.2211676905863212
# R-squared: 0.9028307996111167

# %% [markdown]
# ##Experiment with different algorithms (e.g.,linear regression, decision trees, random forest) and compare their performance

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
models={
    'LinearRegression':LinearRegression(),
    'DecisionTreeRegressor':DecisionTreeRegressor(random_state=42),
    'RandomForestRegressor':RandomForestRegressor(random_state=42),
}

results={}
for name,model in models.items():
  model.fit(X_train_scaled,y_train)
  y_pred=model.predict(X_test_scaled)

  mse=mean_squared_error(y_test,y_pred)
  r2=r2_score(y_test,y_pred)

  results[name]={"Mse":mse,"r2":r2}

results_df=pd.DataFrame(results)
print(results_df)
# Out:
#      LinearRegression  DecisionTreeRegressor  RandomForestRegressor
# Mse          0.221168               0.059312               0.031092
# r2           0.902831               0.973942               0.986340

# %% [markdown]
# #Task-2(Customer Preference Analysis)

# %% [markdown]
# ##Analyze the relationship between the type of cuisine and the restaurant's rating

# %%
cuisines=df['Cuisines']

# %%
cuisines.value_counts().head()
# Out:
# Cuisines
# North Indian             945
# North Indian, Chinese    511
# Chinese                  354
# Fast Food                354
# North Indian, Mughlai    334
# Name: count, dtype: int64

# %%
top_10_cuisines=cuisines=df['Cuisines'].value_counts().head(10).index

# %%
cuisine_ratings = pd.DataFrame({'cuisine': df['Cuisines'], 'Rating': df['Aggregate rating']})

# %%
cuisine_rating_top10=cuisine_ratings[cuisine_ratings['cuisine'].isin(top_10_cuisines)]

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='cuisine',y='Rating',data=cuisine_rating_top10)
plt.xticks(rotation=90)
plt.xlabel('Cuisine type')
plt.ylabel('Rating')
plt.title('Relationship between Cuisine and Rating')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  ## Identify the most popular cuisines among customers based on the number of votes

# %%
cuisine_votes=pd.DataFrame({'cuisine':df['Cuisines'],'Votes':df['Votes']})

# %%
cuisine_votes_sum=cuisine_votes.groupby('cuisine')['Votes'].sum()

# %%
Popular_cuisines=cuisine_votes_sum.sort_values(ascending=False).head(10)

# %%
print('Popular cuisines among customers based on the number of votes')
print(Popular_cuisines)
# Out:
# Popular cuisines among customers based on the number of votes
# cuisine
# North Indian, Mughlai             53747
# North Indian                      48967
# North Indian, Chinese             42012
# Cafe                              30657
# Chinese                           21925
# North Indian, Mughlai, Chinese    20115
# Fast Food                         17852
# South Indian                      16433
# Mughlai, North Indian             15275
# Italian                           14799
# Name: Votes, dtype: int64

# %%
plt.figure(figsize=(15, 6))
plt.bar(Popular_cuisines.index, Popular_cuisines.values)
plt.xlabel('Cuisine type')
plt.ylabel('Total Votes')
plt.title('Most Popular Cuisines based on Votes')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## Determine if there are any specific cuisines that tend to receive higher ratings

# %%
cuisine_rating=pd.DataFrame({'cuisine':df['Cuisines'],'Rating':df['Aggregate rating']})

# %%
avg_rating_cuisine=cuisine_rating.groupby('cuisine')['Rating'].mean()

# %%
sorted_cuisines=avg_rating_cuisine.sort_values(ascending=False)

# %%
print("Top 10 cuisines with the Highest avg Rating")
print(sorted_cuisines.head(10))
# Out:
# Top 10 cuisines with the Highest avg Rating
# cuisine
# Italian, Deli               4.9
# Hawaiian, Seafood           4.9
# American, Sandwich, Tea     4.9
# Continental, Indian         4.9
# European, Asian, Indian     4.9
# European, Contemporary      4.9
# European, German            4.9
# BBQ, Breakfast, Southern    4.9
# American, Coffee and Tea    4.9
# Sunda, Indonesian           4.9
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(16, 6))
plt.bar(sorted_cuisines.index[:10], sorted_cuisines.values[:10])
plt.xlabel('Cuisine type')
plt.ylabel('Average Rating')
plt.title('Top 10 Cuisines with the Highest Average Rating')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# #Task-3(Data Visualization)

# %% [markdown]
# ##Create visualizations to represent the distribution of ratings using different charts (histogram, bar plot, etc.)

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Aggregate rating'],bins=20,kde=True)
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Ratings')
# Out:
# Text(0.5, 1.0, 'Distribution of Ratings')

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Aggregate rating',data=df,palette='viridis')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Distribution of Ratings')
plt.show()

# %% [markdown]
# ##Compare the average ratings of different cuisines or cities using appropriate visualizations

# %%
avg_rating_by_city = df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False)

plt.figure(figsize=(12,6))
sns.barplot(x=avg_rating_by_city.head(10).index,y=avg_rating_by_city.head(10).values,palette='viridis')
plt.xlabel('City')
plt.ylabel('Average Rating')
plt.title('Average Ratings by City')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ##Visualize the relationship between various features and the target variable to gain insights.

# %%
features=['Average Cost for two', 'Has Table booking', 'Has Online delivery','Aggregate rating', 'Votes']
sns.pairplot(df[features])
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>
